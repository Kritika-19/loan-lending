# %%
# Import Libraries

import pandas as pd
import pickle

# Import Models
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier

# Import Model Evaluation and Utilities
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, make_scorer, recall_score, classification_report

# %%
# Fetch Data
raw_data = pd.read_csv('../data/processed/raw_data.csv')
std_data = pd.read_csv('../data/processed/standardized_data.csv')

# Convert user-profile to numbers
raw_y = raw_data['user_profile'].map({'Payer': 0, 'Defaulter': 1})
std_y = std_data['user_profile'].map({'Payer': 0, 'Defaulter': 1})

# Drop user_profile from the data
raw_X = raw_data.drop('user_profile', axis=1)
std_X = std_data.drop('user_profile', axis=1)

# %%
# Train-test split
raw_X_train, raw_X_test, raw_y_train, raw_y_test = train_test_split(raw_X, raw_y, test_size=0.2, stratify= raw_y, random_state=42)
std_X_train, std_X_test, std_y_train, std_y_test = train_test_split(std_X, std_y, test_size=0.2, stratify= std_y, random_state=42)

# %%
print("Train Data Shape: ", raw_X_train.shape)
print("Test Data Shape: ", raw_X_test.shape)
# Out:
# Train Data Shape:  (1808511, 18)
# Test Data Shape:  (452128, 18)

# %% [markdown]
# # Logistic Regression

# %%
X_train, y_train, X_test, y_test = std_X_train, std_y_train, std_X_test, std_y_test

# %%
# Model Training
clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Save the model
pickle.dump(clf, open('../models/logistic_regression.pkl', 'wb'))

# %%
# Model Evaluation
y_pred = clf.predict(X_test)
print('Accuracy: ', accuracy_score(y_test, y_pred)*100)
print('Classification Report: \n ', classification_report(y_test, y_pred))
# Out:
# Accuracy:  87.99764668412486
# Classification Report:
#                 precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94    391014
#            1       0.96      0.12      0.21     61114
#
#     accuracy                           0.88    452128
#    macro avg       0.92      0.56      0.57    452128
# weighted avg       0.89      0.88      0.84    452128

# %% [markdown]
# ### Observations:
#
# - Although, the accuracy and precision/recall of payers seems quite high; but as we decided, the most crucial for us is the **Recall of Defaulters**
# - From this model, the recall of defaulters = **12%**

# %% [markdown]
# # Naive Bayes

# %%
X_train, y_train, X_test, y_test = raw_X_train, raw_y_train, raw_X_test, raw_y_test

# %%
# Model Training
clf = GaussianNB()
clf.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# Save the model
pickle.dump(clf, open('../models/naive_bayes.pkl', 'wb'))

# %%
# Model Evaluation
y_pred = clf.predict(X_test)
print('Accuracy: ', accuracy_score(y_test, y_pred)*100)
print('Classification Report: \n ', classification_report(y_test, y_pred))
# Out:
# Accuracy:  82.63788130794819
# Classification Report:
#                 precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90    391014
#            1       0.34      0.31      0.32     61114
#
#     accuracy                           0.83    452128
#    macro avg       0.62      0.61      0.61    452128
# weighted avg       0.82      0.83      0.82    452128

# %% [markdown]
# ### Observations:
#
# - Although, the accuracy and precision/recall of payers seems have reduced in comparison to Logistic Regression
# - The performance of this model is much better in detecting **Defaulter** with recall of Defaulters = **31%**

# %% [markdown]
# # Decission Trees

# %%
X_train, y_train, X_test, y_test = std_X_train, std_y_train, std_X_test, std_y_test

# %%
# Grid Search for Hyperparameter Tuning
param_grid = {
    'criterion': ['gini'],
    'max_depth': [5, 10, 20, 30, 50, 100],
    'min_samples_leaf': [2, 4, 8],
}

clf = DecisionTreeClassifier(random_state=42)

# Grid search based on recall of `Defaulter`
# # Custom scorer to optimize recall for class 1
recall_scorer = make_scorer(recall_score, average='macro')
grid_search = GridSearchCV(clf, param_grid, scoring=recall_scorer, cv=5, n_jobs=-1, verbose=10)
grid_search.fit(X_train, y_train)

# Print best parameters
print(f"Best Parameters: {grid_search.best_params_}")
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 4/5; 1/18] START criterion=gini, max_depth=5, min_samples_leaf=2............
# [CV 3/5; 1/18] START criterion=gini, max_depth=5, min_samples_leaf=2............[CV 4/5; 2/18] START criterion=gini, max_depth=5, min_samples_leaf=4............
#
# [CV 3/5; 2/18] START criterion=gini, max_depth=5, min_samples_leaf=4............
# [CV 2/5; 1/18] START criterion=gini, max_depth=5, min_samples_leaf=2............
# [CV 1/5; 2/18] START criterion=gini, max_depth=5, min_samples_leaf=4............
# [CV 2/5; 2/18] START criterion=gini, max_depth=5, min_samples_leaf=4............
# [CV 1/5; 1/18] START criterion=gini, max_depth=5, min_samples_leaf=2............
# [CV 5/5; 2/18] START criterion=gini, max_depth=5, min_samples_leaf=4............
# [CV 5/5; 1/18] START criterion=gini, max_depth=5, min_samples_leaf=2............
# [CV 2/5; 1/18] END criterion=gini, max_depth=5, min_samples_leaf=2;, score=0.555 total time=   7.4s
# [CV 4/5; 1/18] END criterion=gini, max_depth=5, min_samples_leaf=2;, score=0.556 total time=   7.5s
# [CV 1/5; 1/18] END criterion=gini, max_depth=5, min_samples_leaf=2;, score=0.557 total time=   7.5s
# [CV 2/5; 2/18] END criterion=gini, max_depth=5, min_samples_leaf=4;, score=0.555 total time=   7.6s
# [CV 1/5; 3/18] START criterion=gini, max_depth=5, min_samples_leaf=8............
# [CV 3/5; 1/18] END criterion=gini, max_depth=5, min_samples_leaf=2;, score=0.557 total time=   7.6s
# [CV 2/5; 3/18] START criterion=gini, max_depth=5, min_samples_leaf=8............
# [CV 3/5; 3/18] START criterion=gini, max_depth=5, min_samples_leaf=8............
# [CV 4/5; 3/18] START criterion=gini, max_depth=5, min_samples_leaf=8............
# [CV 5/5; 1/18] END criterion=gini, max_depth=5, min_samples_leaf=2;, score=0.555 total time=   7.7s
# [CV 4/5; 2/18] END criterion=gini, max_depth=5, min_samples_leaf=4;, score=0.556 total time=   7.8s
# [CV 5/5; 3/18] START criterion=gini, max_depth=5, min_samples_leaf=8............
# [CV 5/5; 2/18] END criterion=gini, max_depth=5, min_samples_leaf=4;, score=0.555 total time=   7.8s
# [CV 1/5; 4/18] START criterion=gini, max_depth=10, min_samples_leaf=2...........
# [CV 3/5; 2/18] END criterion=gini, max_depth=5, min_samples_leaf=4;, score=0.557 total time=   7.9s
# [CV 1/5; 2/18] END criterion=gini, max_depth=5, min_samples_leaf=4;, score=0.557 total time=   7.9s
# [CV 2/5; 4/18] START criterion=gini, max_depth=10, min_samples_leaf=2...........
# [CV 3/5; 4/18] START criterion=gini, max_depth=10, min_samples_leaf=2...........
# [CV 4/5; 4/18] START criterion=gini, max_depth=10, min_samples_leaf=2...........
# [CV 5/5; 4/18] START criterion=gini, max_depth=10, min_samples_leaf=2...........
# [CV 3/5; 3/18] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.557 total time=   5.8s
# [CV 1/5; 3/18] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.557 total time=   5.9s
# [CV 1/5; 5/18] START criterion=gini, max_depth=10, min_samples_leaf=4...........
# [CV 4/5; 3/18] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.556 total time=   5.9s
# [CV 2/5; 3/18] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.555 total time=   5.9s
# [CV 2/5; 5/18] START criterion=gini, max_depth=10, min_samples_leaf=4...........
# [CV 5/5; 3/18] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.555 total time=   5.8s
# [CV 3/5; 5/18] START criterion=gini, max_depth=10, min_samples_leaf=4...........
# [CV 4/5; 5/18] START criterion=gini, max_depth=10, min_samples_leaf=4...........
# [CV 5/5; 5/18] START criterion=gini, max_depth=10, min_samples_leaf=4...........
# [CV 1/5; 4/18] END criterion=gini, max_depth=10, min_samples_leaf=2;, score=0.558 total time=  11.1s
# [CV 2/5; 4/18] END criterion=gini, max_depth=10, min_samples_leaf=2;, score=0.556 total time=  11.1s
# [CV 1/5; 6/18] START criterion=gini, max_depth=10, min_samples_leaf=8...........
# [CV 2/5; 6/18] START criterion=gini, max_depth=10, min_samples_leaf=8...........
# [CV 5/5; 4/18] END criterion=gini, max_depth=10, min_samples_leaf=2;, score=0.557 total time=  11.1s
# [CV 4/5; 4/18] END criterion=gini, max_depth=10, min_samples_leaf=2;, score=0.558 total time=  11.1s
# [CV 3/5; 6/18] START criterion=gini, max_depth=10, min_samples_leaf=8...........
# [CV 3/5; 4/18] END criterion=gini, max_depth=10, min_samples_leaf=2;, score=0.559 total time=  11.3s
# [CV 4/5; 6/18] START criterion=gini, max_depth=10, min_samples_leaf=8...........
# [CV 5/5; 6/18] START criterion=gini, max_depth=10, min_samples_leaf=8...........
# [CV 2/5; 5/18] END criterion=gini, max_depth=10, min_samples_leaf=4;, score=0.556 total time=  10.6s
# [CV 1/5; 5/18] END criterion=gini, max_depth=10, min_samples_leaf=4;, score=0.558 total time=  10.7s
# [CV 1/5; 7/18] START criterion=gini, max_depth=20, min_samples_leaf=2...........
# [CV 2/5; 7/18] START criterion=gini, max_depth=20, min_samples_leaf=2...........
# [CV 4/5; 5/18] END criterion=gini, max_depth=10, min_samples_leaf=4;, score=0.558 total time=  10.7s
# [CV 3/5; 7/18] START criterion=gini, max_depth=20, min_samples_leaf=2...........
# [CV 3/5; 5/18] END criterion=gini, max_depth=10, min_samples_leaf=4;, score=0.559 total time=  11.0s
# [CV 5/5; 5/18] END criterion=gini, max_depth=10, min_samples_leaf=4;, score=0.557 total time=  10.9s
# [CV 4/5; 7/18] START criterion=gini, max_depth=20, min_samples_leaf=2...........
# [CV 5/5; 7/18] START criterion=gini, max_depth=20, min_samples_leaf=2...........
# [CV 1/5; 6/18] END criterion=gini, max_depth=10, min_samples_leaf=8;, score=0.558 total time=  10.0s
# [CV 2/5; 6/18] END criterion=gini, max_depth=10, min_samples_leaf=8;, score=0.556 total time=  10.0s
# [CV 4/5; 6/18] END criterion=gini, max_depth=10, min_samples_leaf=8;, score=0.558 total time=   9.8s
# [CV 3/5; 6/18] END criterion=gini, max_depth=10, min_samples_leaf=8;, score=0.559 total time=   9.9s
# [CV 2/5; 8/18] START criterion=gini, max_depth=20, min_samples_leaf=4...........
# [CV 3/5; 8/18] START criterion=gini, max_depth=20, min_samples_leaf=4...........
# [CV 1/5; 8/18] START criterion=gini, max_depth=20, min_samples_leaf=4...........
# [CV 5/5; 6/18] END criterion=gini, max_depth=10, min_samples_leaf=8;, score=0.557 total time=   9.9s
# [CV 4/5; 8/18] START criterion=gini, max_depth=20, min_samples_leaf=4...........
# [CV 5/5; 8/18] START criterion=gini, max_depth=20, min_samples_leaf=4...........
# [CV 2/5; 7/18] END criterion=gini, max_depth=20, min_samples_leaf=2;, score=0.565 total time=  16.3s
# [CV 1/5; 9/18] START criterion=gini, max_depth=20, min_samples_leaf=8...........
# [CV 1/5; 7/18] END criterion=gini, max_depth=20, min_samples_leaf=2;, score=0.566 total time=  16.5s
# [CV 2/5; 9/18] START criterion=gini, max_depth=20, min_samples_leaf=8...........
# [CV 3/5; 7/18] END criterion=gini, max_depth=20, min_samples_leaf=2;, score=0.568 total time=  16.6s
# [CV 4/5; 7/18] END criterion=gini, max_depth=20, min_samples_leaf=2;, score=0.566 total time=  16.4s
# [CV 5/5; 7/18] END criterion=gini, max_depth=20, min_samples_leaf=2;, score=0.567 total time=  16.6s
# [CV 4/5; 9/18] START criterion=gini, max_depth=20, min_samples_leaf=8...........
# [CV 3/5; 9/18] START criterion=gini, max_depth=20, min_samples_leaf=8...........
# [CV 5/5; 9/18] START criterion=gini, max_depth=20, min_samples_leaf=8...........
# [CV 2/5; 8/18] END criterion=gini, max_depth=20, min_samples_leaf=4;, score=0.566 total time=  16.9s
# [CV 1/5; 10/18] START criterion=gini, max_depth=30, min_samples_leaf=2..........
# [CV 1/5; 8/18] END criterion=gini, max_depth=20, min_samples_leaf=4;, score=0.567 total time=  17.0s
# [CV 3/5; 8/18] END criterion=gini, max_depth=20, min_samples_leaf=4;, score=0.568 total time=  17.1s
# [CV 2/5; 10/18] START criterion=gini, max_depth=30, min_samples_leaf=2..........
# [CV 3/5; 10/18] START criterion=gini, max_depth=30, min_samples_leaf=2..........
# [CV 4/5; 8/18] END criterion=gini, max_depth=20, min_samples_leaf=4;, score=0.567 total time=  17.2s
# [CV 5/5; 8/18] END criterion=gini, max_depth=20, min_samples_leaf=4;, score=0.567 total time=  17.2s
# [CV 4/5; 10/18] START criterion=gini, max_depth=30, min_samples_leaf=2..........
# [CV 5/5; 10/18] START criterion=gini, max_depth=30, min_samples_leaf=2..........
# [CV 1/5; 9/18] END criterion=gini, max_depth=20, min_samples_leaf=8;, score=0.568 total time=  18.2s
# [CV 2/5; 9/18] END criterion=gini, max_depth=20, min_samples_leaf=8;, score=0.567 total time=  18.1s
# [CV 1/5; 11/18] START criterion=gini, max_depth=30, min_samples_leaf=4..........
# [CV 2/5; 11/18] START criterion=gini, max_depth=30, min_samples_leaf=4..........
# [CV 4/5; 9/18] END criterion=gini, max_depth=20, min_samples_leaf=8;, score=0.569 total time=  17.9s
# [CV 3/5; 11/18] START criterion=gini, max_depth=30, min_samples_leaf=4..........
# [CV 3/5; 9/18] END criterion=gini, max_depth=20, min_samples_leaf=8;, score=0.569 total time=  18.2s
# [CV 4/5; 11/18] START criterion=gini, max_depth=30, min_samples_leaf=4..........
# [CV 5/5; 9/18] END criterion=gini, max_depth=20, min_samples_leaf=8;, score=0.568 total time=  18.3s
# [CV 5/5; 11/18] START criterion=gini, max_depth=30, min_samples_leaf=4..........
# [CV 3/5; 10/18] END criterion=gini, max_depth=30, min_samples_leaf=2;, score=0.581 total time=  21.2s
# [CV 2/5; 10/18] END criterion=gini, max_depth=30, min_samples_leaf=2;, score=0.578 total time=  21.3s
# [CV 1/5; 12/18] START criterion=gini, max_depth=30, min_samples_leaf=8..........
# [CV 2/5; 12/18] START criterion=gini, max_depth=30, min_samples_leaf=8..........
# [CV 1/5; 10/18] END criterion=gini, max_depth=30, min_samples_leaf=2;, score=0.581 total time=  21.6s
# [CV 3/5; 12/18] START criterion=gini, max_depth=30, min_samples_leaf=8..........
# [CV 4/5; 10/18] END criterion=gini, max_depth=30, min_samples_leaf=2;, score=0.581 total time=  21.5s
# [CV 4/5; 12/18] START criterion=gini, max_depth=30, min_samples_leaf=8..........
# [CV 5/5; 10/18] END criterion=gini, max_depth=30, min_samples_leaf=2;, score=0.581 total time=  21.4s
# [CV 5/5; 12/18] START criterion=gini, max_depth=30, min_samples_leaf=8..........
# [CV 2/5; 11/18] END criterion=gini, max_depth=30, min_samples_leaf=4;, score=0.581 total time=  19.4s
# [CV 1/5; 13/18] START criterion=gini, max_depth=50, min_samples_leaf=2..........
# [CV 3/5; 11/18] END criterion=gini, max_depth=30, min_samples_leaf=4;, score=0.583 total time=  19.6s
# [CV 1/5; 11/18] END criterion=gini, max_depth=30, min_samples_leaf=4;, score=0.582 total time=  19.8s
# [CV 2/5; 13/18] START criterion=gini, max_depth=50, min_samples_leaf=2..........
# [CV 3/5; 13/18] START criterion=gini, max_depth=50, min_samples_leaf=2..........
# [CV 4/5; 11/18] END criterion=gini, max_depth=30, min_samples_leaf=4;, score=0.582 total time=  19.5s
# [CV 4/5; 13/18] START criterion=gini, max_depth=50, min_samples_leaf=2..........
# [CV 5/5; 11/18] END criterion=gini, max_depth=30, min_samples_leaf=4;, score=0.582 total time=  19.9s
# [CV 5/5; 13/18] START criterion=gini, max_depth=50, min_samples_leaf=2..........
# [CV 1/5; 12/18] END criterion=gini, max_depth=30, min_samples_leaf=8;, score=0.582 total time=  19.1s
# [CV 2/5; 12/18] END criterion=gini, max_depth=30, min_samples_leaf=8;, score=0.581 total time=  19.1s
# [CV 1/5; 14/18] START criterion=gini, max_depth=50, min_samples_leaf=4..........
# [CV 3/5; 12/18] END criterion=gini, max_depth=30, min_samples_leaf=8;, score=0.585 total time=  19.0s
# [CV 2/5; 14/18] START criterion=gini, max_depth=50, min_samples_leaf=4..........
# [CV 3/5; 14/18] START criterion=gini, max_depth=50, min_samples_leaf=4..........
# [CV 4/5; 12/18] END criterion=gini, max_depth=30, min_samples_leaf=8;, score=0.584 total time=  18.9s
# [CV 4/5; 14/18] START criterion=gini, max_depth=50, min_samples_leaf=4..........
# [CV 5/5; 12/18] END criterion=gini, max_depth=30, min_samples_leaf=8;, score=0.584 total time=  19.1s
# [CV 5/5; 14/18] START criterion=gini, max_depth=50, min_samples_leaf=4..........
# [CV 1/5; 13/18] END criterion=gini, max_depth=50, min_samples_leaf=2;, score=0.586 total time=  21.4s
# [CV 1/5; 15/18] START criterion=gini, max_depth=50, min_samples_leaf=8..........
# [CV 4/5; 13/18] END criterion=gini, max_depth=50, min_samples_leaf=2;, score=0.586 total time=  21.2s
# [CV 3/5; 13/18] END criterion=gini, max_depth=50, min_samples_leaf=2;, score=0.587 total time=  21.3s
# [CV 2/5; 15/18] START criterion=gini, max_depth=50, min_samples_leaf=8..........
# [CV 3/5; 15/18] START criterion=gini, max_depth=50, min_samples_leaf=8..........
# [CV 5/5; 13/18] END criterion=gini, max_depth=50, min_samples_leaf=2;, score=0.587 total time=  21.4s
# [CV 4/5; 15/18] START criterion=gini, max_depth=50, min_samples_leaf=8..........
# [CV 2/5; 13/18] END criterion=gini, max_depth=50, min_samples_leaf=2;, score=0.585 total time=  22.6s
# [CV 5/5; 15/18] START criterion=gini, max_depth=50, min_samples_leaf=8..........
# [CV 1/5; 14/18] END criterion=gini, max_depth=50, min_samples_leaf=4;, score=0.587 total time=  20.6s
# [CV 1/5; 16/18] START criterion=gini, max_depth=100, min_samples_leaf=2.........
# [CV 2/5; 14/18] END criterion=gini, max_depth=50, min_samples_leaf=4;, score=0.586 total time=  20.7s
# [CV 2/5; 16/18] START criterion=gini, max_depth=100, min_samples_leaf=2.........
# [CV 3/5; 14/18] END criterion=gini, max_depth=50, min_samples_leaf=4;, score=0.588 total time=  20.7s
# [CV 3/5; 16/18] START criterion=gini, max_depth=100, min_samples_leaf=2.........
# [CV 4/5; 14/18] END criterion=gini, max_depth=50, min_samples_leaf=4;, score=0.588 total time=  20.5s
# [CV 4/5; 16/18] START criterion=gini, max_depth=100, min_samples_leaf=2.........
# [CV 5/5; 14/18] END criterion=gini, max_depth=50, min_samples_leaf=4;, score=0.586 total time=  20.7s
# [CV 5/5; 16/18] START criterion=gini, max_depth=100, min_samples_leaf=2.........
# [CV 1/5; 15/18] END criterion=gini, max_depth=50, min_samples_leaf=8;, score=0.587 total time=  20.8s
# [CV 1/5; 17/18] START criterion=gini, max_depth=100, min_samples_leaf=4.........
# [CV 2/5; 15/18] END criterion=gini, max_depth=50, min_samples_leaf=8;, score=0.585 total time=  20.8s
# [CV 2/5; 17/18] START criterion=gini, max_depth=100, min_samples_leaf=4.........
# [CV 3/5; 15/18] END criterion=gini, max_depth=50, min_samples_leaf=8;, score=0.587 total time=  20.9s
# [CV 3/5; 17/18] START criterion=gini, max_depth=100, min_samples_leaf=4.........
# [CV 4/5; 15/18] END criterion=gini, max_depth=50, min_samples_leaf=8;, score=0.587 total time=  20.8s
# [CV 4/5; 17/18] START criterion=gini, max_depth=100, min_samples_leaf=4.........
# [CV 5/5; 15/18] END criterion=gini, max_depth=50, min_samples_leaf=8;, score=0.587 total time=  20.9s
# [CV 5/5; 17/18] START criterion=gini, max_depth=100, min_samples_leaf=4.........
# [CV 2/5; 16/18] END criterion=gini, max_depth=100, min_samples_leaf=2;, score=0.584 total time=  22.2s
# [CV 1/5; 18/18] START criterion=gini, max_depth=100, min_samples_leaf=8.........
# [CV 3/5; 16/18] END criterion=gini, max_depth=100, min_samples_leaf=2;, score=0.587 total time=  22.3s
# [CV 2/5; 18/18] START criterion=gini, max_depth=100, min_samples_leaf=8.........
# [CV 1/5; 16/18] END criterion=gini, max_depth=100, min_samples_leaf=2;, score=0.586 total time=  22.4s
# [CV 3/5; 18/18] START criterion=gini, max_depth=100, min_samples_leaf=8.........
# [CV 4/5; 16/18] END criterion=gini, max_depth=100, min_samples_leaf=2;, score=0.586 total time=  22.2s
# [CV 4/5; 18/18] START criterion=gini, max_depth=100, min_samples_leaf=8.........
# [CV 5/5; 16/18] END criterion=gini, max_depth=100, min_samples_leaf=2;, score=0.587 total time=  22.4s
# [CV 5/5; 18/18] START criterion=gini, max_depth=100, min_samples_leaf=8.........
# [CV 1/5; 17/18] END criterion=gini, max_depth=100, min_samples_leaf=4;, score=0.587 total time=  21.0s
# [CV 3/5; 17/18] END criterion=gini, max_depth=100, min_samples_leaf=4;, score=0.588 total time=  20.9s
# [CV 2/5; 17/18] END criterion=gini, max_depth=100, min_samples_leaf=4;, score=0.586 total time=  21.1s
# [CV 4/5; 17/18] END criterion=gini, max_depth=100, min_samples_leaf=4;, score=0.587 total time=  20.6s
# [CV 5/5; 17/18] END criterion=gini, max_depth=100, min_samples_leaf=4;, score=0.586 total time=  20.8s
# [CV 2/5; 18/18] END criterion=gini, max_depth=100, min_samples_leaf=8;, score=0.585 total time=  17.9s
# [CV 3/5; 18/18] END criterion=gini, max_depth=100, min_samples_leaf=8;, score=0.587 total time=  18.0s
# [CV 1/5; 18/18] END criterion=gini, max_depth=100, min_samples_leaf=8;, score=0.587 total time=  18.2s
# [CV 4/5; 18/18] END criterion=gini, max_depth=100, min_samples_leaf=8;, score=0.587 total time=  17.7s
# [CV 5/5; 18/18] END criterion=gini, max_depth=100, min_samples_leaf=8;, score=0.587 total time=  17.7s
# Best Parameters: {'criterion': 'gini', 'max_depth': 100, 'min_samples_leaf': 4}

# %%
# Model Training
clf = DecisionTreeClassifier(**grid_search.best_params_, random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=100, min_samples_leaf=4, random_state=42)

# %%
# Save the model
pickle.dump(clf, open('../models/decision_trees.pkl', 'wb'))

# %%
# Model Evaluation
y_pred = clf.predict(X_test)
print('Accuracy: ', accuracy_score(y_test, y_pred)*100)
print('Classification Report: \n ', classification_report(y_test, y_pred))
# Out:
# Accuracy:  83.03533512633591
# Classification Report:
#                 precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90    391014
#            1       0.33      0.25      0.29     61114
#
#     accuracy                           0.83    452128
#    macro avg       0.61      0.59      0.60    452128
# weighted avg       0.81      0.83      0.82    452128

# %% [markdown]
# ### Observations:
#
# - Although, the accuracy and precision/recall of payers seems have reduced in comparison to Logistic Regression
# - The performance of this model is not better in detecting **Defaulter** as compared to **Naive Bayes** with recall of Defaulters = **25%**

# %% [markdown]
# # KNN

# %%
X_train, y_train, X_test, y_test = std_X_train, std_y_train, std_X_test, std_y_test

# %%
# Model Training
clf = KNeighborsClassifier()

# Grid Search for Hyperparameter Tuning
param_grid = {
    'n_neighbors': [50, 100, 400, 700, 1000]
}

recall_scorer = make_scorer(recall_score, average='macro')
grid_search = GridSearchCV(clf, param_grid, scoring=recall_scorer, cv=5, n_jobs=-1, verbose=10)
grid_search.fit(X_train, y_train)

# Print best parameters
print(f"Best Parameters: {grid_search.best_params_}")
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 3/5; 2/5] START n_neighbors=100.............................................
# [CV 3/5; 1/5] START n_neighbors=50..............................................
# [CV 1/5; 2/5] START n_neighbors=100.............................................
# [CV 1/5; 1/5] START n_neighbors=50..............................................[CV 4/5; 2/5] START n_neighbors=100.............................................
#
# [CV 4/5; 1/5] START n_neighbors=50..............................................
# [CV 5/5; 1/5] START n_neighbors=50..............................................
# [CV 2/5; 2/5] START n_neighbors=100.............................................
# [CV 2/5; 1/5] START n_neighbors=50..............................................
# [CV 5/5; 2/5] START n_neighbors=100.............................................
# [CV 5/5; 1/5] END ...............n_neighbors=50;, score=0.558 total time=75.2min
# [CV 1/5; 3/5] START n_neighbors=400.............................................
# [CV 1/5; 1/5] END ...............n_neighbors=50;, score=0.559 total time=75.2min
# [CV 2/5; 3/5] START n_neighbors=400.............................................
# [CV 4/5; 1/5] END ...............n_neighbors=50;, score=0.559 total time=75.3min
# [CV 3/5; 3/5] START n_neighbors=400.............................................
# [CV 2/5; 1/5] END ...............n_neighbors=50;, score=0.558 total time=75.3min
# [CV 4/5; 3/5] START n_neighbors=400.............................................
# [CV 3/5; 1/5] END ...............n_neighbors=50;, score=0.560 total time=75.3min
# [CV 5/5; 3/5] START n_neighbors=400.............................................
# [CV 4/5; 2/5] END ..............n_neighbors=100;, score=0.558 total time=75.8min
# [CV 1/5; 4/5] START n_neighbors=700.............................................
# [CV 5/5; 2/5] END ..............n_neighbors=100;, score=0.557 total time=75.8min
# [CV 3/5; 2/5] END ..............n_neighbors=100;, score=0.559 total time=75.8min
# [CV 2/5; 4/5] START n_neighbors=700.............................................
# [CV 3/5; 4/5] START n_neighbors=700.............................................
# [CV 1/5; 2/5] END ..............n_neighbors=100;, score=0.557 total time=75.8min
# [CV 4/5; 4/5] START n_neighbors=700.............................................
# [CV 2/5; 2/5] END ..............n_neighbors=100;, score=0.556 total time=75.8min
# [CV 5/5; 4/5] START n_neighbors=700.............................................
# [CV 1/5; 3/5] END ..............n_neighbors=400;, score=0.555 total time=94.2min
# [CV 1/5; 5/5] START n_neighbors=1000............................................
# [CV 3/5; 3/5] END ..............n_neighbors=400;, score=0.557 total time=94.2min
# [CV 2/5; 3/5] END ..............n_neighbors=400;, score=0.554 total time=94.2min
# [CV 2/5; 5/5] START n_neighbors=1000............................................
# [CV 3/5; 5/5] START n_neighbors=1000............................................
# [CV 4/5; 3/5] END ..............n_neighbors=400;, score=0.555 total time=94.2min
# [CV 4/5; 5/5] START n_neighbors=1000............................................
# [CV 5/5; 3/5] END ..............n_neighbors=400;, score=0.555 total time=94.3min
# [CV 5/5; 5/5] START n_neighbors=1000............................................
# [CV 1/5; 4/5] END ..............n_neighbors=700;, score=0.555 total time=98.4min
# [CV 4/5; 4/5] END ..............n_neighbors=700;, score=0.555 total time=98.4min
# [CV 3/5; 4/5] END ..............n_neighbors=700;, score=0.556 total time=98.4min
# [CV 2/5; 4/5] END ..............n_neighbors=700;, score=0.553 total time=98.5min
# [CV 5/5; 4/5] END ..............n_neighbors=700;, score=0.554 total time=98.5min
# [CV 5/5; 5/5] END .............n_neighbors=1000;, score=0.554 total time=70.8min
# [CV 4/5; 5/5] END .............n_neighbors=1000;, score=0.555 total time=70.8min
# [CV 1/5; 5/5] END .............n_neighbors=1000;, score=0.555 total time=71.1min
# [CV 2/5; 5/5] END .............n_neighbors=1000;, score=0.553 total time=71.0min
# [CV 3/5; 5/5] END .............n_neighbors=1000;, score=0.556 total time=71.1min
# Best Parameters: {'n_neighbors': 50}

# %%
# Model Training
clf = KNeighborsClassifier(**grid_search.best_params_)
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=50)

# %%
# Save the model
pickle.dump(clf, open('../models/knn.pkl', 'wb'))

# %%
# Model Evaluation
y_pred = clf.predict(X_test)
print('Accuracy: ', accuracy_score(y_test, y_pred)*100)
print('Classification Report: \n ', classification_report(y_test, y_pred))
# Out:
# Accuracy:  87.99609844999647
# Classification Report:
#                 precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94    391014
#            1       0.93      0.12      0.21     61114
#
#     accuracy                           0.88    452128
#    macro avg       0.91      0.56      0.57    452128
# weighted avg       0.89      0.88      0.84    452128

# %% [markdown]
# ### Observations:
#
# - Although, the accuracy and precision/recall of payers seems quite high; but as we decided, the most crucial for us is the **Recall of Defaulters**
# - From this model, the recall of defaulters = **12%**

# %% [markdown]
# # Random Forest

# %%
X_train, y_train, X_test, y_test = std_X_train, std_y_train, std_X_test, std_y_test

# %%
# Model Training
clf = RandomForestClassifier(random_state=42)

# Grid Search for Hyperparameter Tuning
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
}
recall_scorer = make_scorer(recall_score, average='macro')
grid_search = GridSearchCV(clf, param_grid, scoring=recall_scorer, cv=5, n_jobs=4, verbose=10)
grid_search.fit(X_train, y_train)

# Print best parameters
print(f"Best Parameters: {grid_search.best_params_}")
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5; 1/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/5; 1/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 3/5; 1/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 4/5; 1/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 3/5; 1/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.567 total time= 1.9min
# [CV 5/5; 1/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/5; 1/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.564 total time= 1.9min
# [CV 1/5; 2/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 1/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.566 total time= 1.9min
# [CV 2/5; 2/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 4/5; 1/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.566 total time= 1.9min
# [CV 3/5; 2/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 5/5; 1/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.565 total time= 1.9min
# [CV 4/5; 2/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/5; 2/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.564 total time= 3.7min
# [CV 1/5; 2/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.565 total time= 3.7min
# [CV 5/5; 2/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 3/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 3/5; 2/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.566 total time= 3.7min
# [CV 2/5; 3/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 4/5; 2/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.565 total time= 3.8min
# [CV 3/5; 3/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 5/5; 2/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.564 total time= 3.8min
# [CV 4/5; 3/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 2/5; 3/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.563 total time= 7.5min
# [CV 5/5; 3/36] START max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 1/5; 3/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.565 total time= 7.5min
# [CV 1/5; 4/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 1/5; 4/36] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.565 total time= 1.8min
# [CV 2/5; 4/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 3/5; 3/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.566 total time= 7.5min
# /Users/singlram/VS Code Repos/topmate/loan-lending/.venv/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV 3/5; 4/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 2/5; 4/36] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.563 total time= 1.8min
# [CV 4/5; 4/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 3/5; 4/36] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.567 total time= 1.8min
# [CV 5/5; 4/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 4/5; 3/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.564 total time= 7.6min
# [CV 1/5; 5/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 4/5; 4/36] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.564 total time= 1.9min
# [CV 2/5; 5/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 5/5; 4/36] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.564 total time= 1.8min
# [CV 3/5; 5/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 1/5; 5/36] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.564 total time= 3.7min
# [CV 5/5; 3/36] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.564 total time= 7.5min
# [CV 4/5; 5/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 5/5; 5/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 2/5; 5/36] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.562 total time= 3.7min
# [CV 1/5; 6/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 3/5; 5/36] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.565 total time= 3.7min
# [CV 2/5; 6/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 4/5; 5/36] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.564 total time= 3.7min
# [CV 3/5; 6/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 5/5; 5/36] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.564 total time= 3.7min
# [CV 4/5; 6/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 1/5; 6/36] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.564 total time= 7.4min
# [CV 5/5; 6/36] START max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 2/5; 6/36] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.561 total time= 7.4min
# [CV 1/5; 7/36] START max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 1/5; 7/36] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.563 total time= 1.8min
# [CV 3/5; 6/36] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.565 total time= 7.4min
# [CV 3/5; 7/36] START max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 2/5; 7/36] START max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 4/5; 6/36] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.563 total time= 7.4min
# [CV 4/5; 7/36] START max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 3/5; 7/36] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.564 total time= 1.8min
# [CV 2/5; 7/36] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.562 total time= 1.8min
# [CV 1/5; 8/36] START max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5;
36] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.559 total time= 5.7min
# [CV 5/5; 30/36] START max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 2/5; 30/36] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.557 total time= 5.6min
# [CV 1/5; 31/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 1/5; 31/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.559 total time= 1.4min
# [CV 2/5; 31/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 3/5; 30/36] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.560 total time= 5.7min
# [CV 3/5; 31/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 4/5; 30/36] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.559 total time= 5.6min
# [CV 4/5; 31/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 2/5; 31/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.558 total time= 1.4min
# [CV 5/5; 31/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 3/5; 31/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.560 total time= 1.4min
# [CV 1/5; 32/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 4/5; 31/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.559 total time= 1.4min
# [CV 2/5; 32/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5; 31/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.558 total time= 1.4min
# [CV 3/5; 32/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5; 30/36] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.558 total time= 5.6min
# [CV 4/5; 32/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 1/5; 32/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.559 total time= 2.8min
# [CV 5/5; 32/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 2/5; 32/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.557 total time= 2.8min
# [CV 1/5; 33/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 3/5; 32/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.560 total time= 2.8min
# [CV 2/5; 33/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 4/5; 32/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.559 total time= 2.8min
# [CV 3/5; 33/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 5/5; 32/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.558 total time= 2.8min
# [CV 4/5; 33/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 1/5; 33/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.559 total time= 5.6min
# [CV 5/5; 33/36] START max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 2/5; 33/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.557 total time= 5.6min
# [CV 1/5; 34/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 3/5; 33/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.560 total time= 5.6min
# [CV 2/5; 34/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 1/5; 34/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.559 total time= 1.4min
# [CV 3/5; 34/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 4/5; 33/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.559 total time= 5.6min
# [CV 4/5; 34/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 2/5; 34/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.557 total time= 1.4min
# [CV 5/5; 34/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 3/5; 34/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.560 total time= 1.4min
# [CV 1/5; 35/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 4/5; 34/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.559 total time= 1.4min
# [CV 2/5; 35/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 5/5; 34/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.558 total time= 1.4min
# [CV 3/5; 35/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 5/5; 33/36] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.558 total time= 5.6min
# [CV 4/5; 35/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 1/5; 35/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.559 total time= 2.8min
# [CV 5/5; 35/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 2/5; 35/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.557 total time= 2.8min
# [CV 1/5; 36/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 3/5; 35/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.560 total time= 2.8min
# [CV 2/5; 36/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 4/5; 35/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.559 total time= 3.0min
# [CV 3/5; 36/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 5/5; 35/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.558 total time= 3.3min
# [CV 4/5; 36/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 1/5; 36/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.559 total time= 7.3min
# [CV 5/5; 36/36] START max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 2/5; 36/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.557 total time= 7.6min
# [CV 3/5; 36/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.560 total time= 7.6min
# [CV 4/5; 36/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.559 total time= 7.2min
# [CV 5/5; 36/36] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.558 total time= 5.5min
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}

# %%
# Model Training
clf = RandomForestClassifier(**grid_search.best_params_, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=42)

# %%
# Save the model
pickle.dump(clf, open('../models/random_forest.pkl', 'wb'))

# %%
# Model Evaluation
y_pred = clf.predict(X_test)
print('Accuracy: ', accuracy_score(y_test, y_pred)*100)
print('Classification Report: \n ', classification_report(y_test, y_pred))
# Out:
# Accuracy:  87.77226803029231
# Classification Report:
#                 precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93    391014
#            1       0.76      0.14      0.23     61114
#
#     accuracy                           0.88    452128
#    macro avg       0.82      0.57      0.58    452128
# weighted avg       0.86      0.88      0.84    452128

# %% [markdown]
# ### Observations:
#
# - Although, the accuracy and precision/recall of payers seems quite high; but as we decided, the most crucial for us is the **Recall of Defaulters**
# - From this model, the recall of defaulters = **14%**
# - Model overall seems to be performing bad in comparison with KNN and Logistic Regression

# %% [markdown]
# # XGBoost

# %%
X_train, y_train, X_test, y_test = std_X_train, std_y_train, std_X_test, std_y_test

# %%
# Model Training
clf = XGBClassifier(random_state=42)

# Grid Search for Hyperparameter Tuning
param_grid = {
    'n_estimators': [10, 50, 100],
    'max_depth': [3, 5, None],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0],
}
recall_scorer = make_scorer(recall_score, average='macro')
grid_search = GridSearchCV(clf, param_grid, scoring=recall_scorer, cv=5, n_jobs=4, verbose=10)
grid_search.fit(X_train, y_train)

# Print best parameters
print(f"Best Parameters: {grid_search.best_params_}")
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV 4/5; 1/108] START colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8
# [CV 1/5; 1/108] START colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8
# [CV 3/5; 1/108] START colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8
# [CV 2/5; 1/108] START colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8
# [CV 4/5; 1/108] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8;, score=0.500 total time=   1.9s
# [CV 3/5; 1/108] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8;, score=0.500 total time=   1.9s
# [CV 2/5; 1/108] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8;, score=0.500 total time=   1.9s
# [CV 1/5; 1/108] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8;, score=0.500 total time=   1.9s
# [CV 1/5; 2/108] START colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1.0
# [CV 2/5; 2/108] START colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1.
108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=10, subsample=0.8;, score=0.558 total time=   2.1s
# [CV 3/5; 104/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=10, subsample=1.0
# [CV 4/5; 104/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=10, subsample=1.0
# [CV 1/5; 104/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=10, subsample=1.0;, score=0.557 total time=   2.0s
# [CV 5/5; 104/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=10, subsample=1.0
# [CV 2/5; 104/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=10, subsample=1.0;, score=0.555 total time=   2.0s
# [CV 4/5; 104/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=10, subsample=1.0;, score=0.557 total time=   2.0s
# [CV 3/5; 104/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=10, subsample=1.0;, score=0.558 total time=   2.0s
# [CV 1/5; 105/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=0.8
# [CV 2/5; 105/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=0.8
# [CV 5/5; 104/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=10, subsample=1.0;, score=0.556 total time=   2.0s
# [CV 3/5; 105/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=0.8
# [CV 4/5; 105/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=0.8
# [CV 2/5; 105/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=0.8;, score=0.558 total time=   4.1s
# [CV 1/5; 105/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=0.8;, score=0.560 total time=   4.1s
# [CV 4/5; 105/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=0.8;, score=0.559 total time=   4.1s
# [CV 3/5; 105/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=0.8;, score=0.560 total time=   4.1s
# [CV 2/5; 106/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=1.0
# [CV 3/5; 106/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=1.0
# [CV 5/5; 105/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=0.8
# [CV 1/5; 106/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=1.0
# [CV 2/5; 106/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=1.0;, score=0.558 total time=   4.0s
# [CV 3/5; 106/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=1.0;, score=0.560 total time=   4.0s
# [CV 4/5; 106/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=1.0
# [CV 5/5; 106/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=1.0
# [CV 1/5; 106/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=1.0;, score=0.559 total time=   4.1s
# [CV 1/5; 107/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.8
# [CV 5/5; 105/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=0.8;, score=0.559 total time=   4.2s
# [CV 2/5; 107/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.8
# [CV 5/5; 106/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=1.0;, score=0.558 total time=   3.9s
# [CV 4/5; 106/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=50, subsample=1.0;, score=0.559 total time=   4.0s
# [CV 3/5; 107/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.8
# [CV 4/5; 107/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.8
# [CV 1/5; 107/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.8;, score=0.560 total time=   6.4s
# [CV 5/5; 107/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.8
# [CV 2/5; 107/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.8;, score=0.559 total time=   6.4s
# [CV 1/5; 108/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=1.0
# [CV 4/5; 107/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.8;, score=0.560 total time=   6.7s
# [CV 2/5; 108/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=1.0
# [CV 3/5; 107/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.8;, score=0.561 total time=   6.7s
# [CV 3/5; 108/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=1.0
# [CV 1/5; 108/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=1.0;, score=0.560 total time=   6.3s
# [CV 5/5; 107/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.8;, score=0.559 total time=   6.7s
# [CV 4/5; 108/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=1.0
# [CV 5/5; 108/108] START colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=1.0
# [CV 2/5; 108/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=1.0;, score=0.559 total time=   6.1s
# [CV 3/5; 108/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=1.0;, score=0.561 total time=   6.1s
# [CV 4/5; 108/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=1.0;, score=0.560 total time=   6.0s
# [CV 5/5; 108/108] END colsample_bytree=1.0, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=1.0;, score=0.559 total time=   5.9s
# Best Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.2, 'max_depth': None, 'n_estimators': 100, 'subsample': 0.8}

# %%
# Model Training
clf = XGBClassifier(**grid_search.best_params_, random_state=42)
clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
# Save the model
pickle.dump(clf, open('../models/xgb.pkl', 'wb'))

# %%
# Model Evaluation
y_pred = clf.predict(X_test)
print('Accuracy: ', accuracy_score(y_test, y_pred)*100)
print('Classification Report: \n ', classification_report(y_test, y_pred))
# Out:
# Accuracy:  88.04674782362517
# Classification Report:
#                 precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94    391014
#            1       0.96      0.12      0.22     61114
#
#     accuracy                           0.88    452128
#    macro avg       0.92      0.56      0.58    452128
# weighted avg       0.89      0.88      0.84    452128

# %% [markdown]
# ### Observations:
#
# - Although, the accuracy and precision/recall of payers seems quite high; but as we decided, the most crucial for us is the **Recall of Defaulters**
# - From this model, the recall of defaulters = **12%**
# - Among all the models with high accuracy and low recall of defaulters, XGBoost is performing better.
